# %% [markdown]
# <a href="https://colab.research.google.com/github/ds4geo/ds4geo_ws2020_git/blob/main/GitHub_Prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GitHub Practical Excercise - Branches and Pull Requests
# This is a simple notebook to practice using branches and pull requests in github.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(np.random.rand(50), np.random.rand(50))
